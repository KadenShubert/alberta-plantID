# %% [markdown]
# # Image & label formatting

# %% [markdown]
# The All_Plant_Data folder must be in the same directory as this file to work.
# </br>Only change the **end of output_root** or the **log_level** parameters to ensure the notebook runs.
# </br>This structure is based on the YOLO structure from [Ultralytics](https://docs.ultralytics.com/datasets/detect/), and will allow the "Plant Identification" notebook to run</br>
# **You may have to install some packages for the notebook to run properly**

# %%
import shutil
import os
import random

# %%
def create_output_dest(dest,sub_folders):
    # Check if dest folder/path exists
    if not(os.path.exists('./TrainModels')):os.mkdir('./TrainModels')
    if not(os.path.exists('./TrainModels/datasets')):os.mkdir('./TrainModels/datasets')  
    if not(os.path.exists(dest)): os.mkdir(dest)    
    # List of folders to create, in order of depth
    folders = [f'{dest}/images/',f'{dest}/labels/']+[f'{dest}/images/{x}' for x in sub_folders] + [f'{dest}/labels/{x}' for x in sub_folders]
    # for each path check if it exists, create the folder if it doesn't
    for path in folders:
        if not(os.path.exists(path)): os.mkdir(path)

# %%
# Input rooot with all folders
input_root = './All_Plant_Data'
all_plants = ['Canada Buffaloberry','Labrador Tea','Prickly Rose','Red-osier Dogwood','Velvet Leaved Blueberry']

# Assign output location
# This format is to ensure the data is usable by YOLOv8
output_root = './TrainModels/datasets/Plant_Dataset_Updated'

# Sets folder structure
images_root = f'{output_root}/images'
labels_root = f'{output_root}/labels'
sub_folders = ['test','train','valid']

# Create output folder(s)
create_output_dest(output_root, sub_folders)

# %%
# Read label file to get order/numbers of plants
label_file = open("label.txt", "r")
label_dict = {x.replace('\n',''):i for i,x in enumerate(label_file)}
label_dict
# Out:
# {'Canada Buffaloberry': 0,
#  'Labrador Tea': 1,
#  'Prickly Rose': 2,
#  'Red-osier Dogwood': 3,
#  'Velvet Leaved Blueberry': 4}

# %%
# Check label # to match with the provided file
def check_label(label_file, label_id, dest_lbl,log_level=0):    
    # Open label file to check id number
    f = open(label_file,'r')    
    if log_level > 2:print(label_file,sep='')
    update_text = ''
    original_text = ''
    updated_id = False
    # Read through each line of the txt file
    for line in f:
        # Store the original text
        original_text += line
        
        # If the first character does not match the label id
        if int(line[0]) != int(label_id):#           
            # Update the first instance of the incorrect label per line
            line = line.replace(line[0],str(label_id),1)
            updated_id = True
        # Store in an updated text variable, incase changes are only made to some cols
        update_text += line        
    f.close()
    # If the text was updated, overwrite the csv with the proper label value
    if len(original_text) == 0: print(f'{label_file} does not contain any data!')
    if updated_id:
        if log_level >= 1:print(f'Updating labels in dataset {dest_lbl}')        
        new = open(dest_lbl,'w')
        new.write(update_text)
        new.close()
        if log_level >= 2: print('Original IDs:\n', original_text,'\n','='*10,sep='')
        if log_level >= 2: print('Updated IDs:\n', update_text,sep='')        
    return updated_id

# %% [markdown]
# ## Single folder (Image and txt)

# %%
# Function for taking combined image/label from a single directory into YOLO folder format
# Assumes all images are .jpg files
def process_image_data(current_plant,log_level=0):
    input_folder = input_root + f'/{current_plant}/'
    print(f'Processing {current_plant} files in {input_folder}')
    
    
    # Get file names, shuffle, remove duplicates
    input_files = os.listdir(input_folder)
    file_names = [i[:-4] for i in input_files] 
    file_names = list(set(file_names)) # Remove duplicates by converting list > set > list
    random.seed(0)
    random.shuffle(file_names)
#     print(input_files)
    
    # Split into test(15%), train(75%), validation(10%)
    num_images = len(file_names)
    train_set = file_names[:int(num_images*0.75)]
    test_set = file_names[int(num_images*0.75):int(num_images*0.90)]
    val_set = file_names[int(num_images*0.90):]

    file_dict = {'train':train_set,'test':test_set,'valid':val_set}

    # Validate splits are not overlapping
    print('Last train file:',train_set[-1],f'| Samples:{len(train_set)}')
    print(f'First test file: {test_set[0]} | Last test file: {test_set[-1]} | Samples:{len(test_set)}')
    print(f'First valid file: {val_set[0]} | Samples:{len(val_set)}\n')

    # Copy each set to respective folders
    for folder in file_dict:    
#         print(f'Processing {folder}ing files...')    
        for file in file_dict[folder]:
            img = f'{file}.jpg'
            label = f'{file}.txt'
            
            # Check if both source files exist otherwise skip the item
            src_lbl = input_folder + label
            dest_lbl = f'{labels_root}/{folder}/{label}'
            src_img = input_folder + img  
            if not(os.path.isfile(src_lbl)) or not(os.path.isfile(src_img)): 
                print(f'Label or Image file not found for {file}, skipping item...')
                print('label:',src_lbl,'| img:',src_img)
                continue
            
            # Copy Images to destination folder                       
            shutil.copyfile(src_img, f'{images_root}/{folder}/{img}')

            # Copy Labels to destination folder
            if check_label(src_lbl, label_dict[current_plant], dest_lbl,log_level): continue
            shutil.copyfile(src_lbl, dest_lbl)
            
    print(f'Completed processing {current_plant} files.')

# %% [markdown]
# ## Canadian Buffalo Berry

# %%
def process_Buffaloberry():
    # Canadian Buffalo Berry was formatted more discretely
    # Place images and labels into correct folders
    current_plant = 'Canada Buffaloberry'

    for folder in sub_folders:
        # ../Canadian_Buffaloberry/test
        current_folder = f'{input_root}/{current_plant}/{folder}'

        # Get all the image files within the subfolder & copy image file to final directory
        img_folder =  f'{current_folder}/images/' 
        for img in os.listdir(img_folder):
            src_img = img_folder + img        
            shutil.copyfile(src_img, f'{images_root}/{folder}/{img}')

        # Get all the label files within the subfolder & copy label file to final directory
        label_folder =  f'{current_folder}/labels/'
        for label in os.listdir(label_folder):        
            src_lbl = label_folder+label
            dest_lbl = f'{labels_root}/{folder}/{label}'
            # Function to check/adjust mislabeled txt files before adding to dataset
            # If label is adjusted, new file is created at destination, copy does not run
            if check_label(src_lbl, label_dict[current_plant], dest_lbl): continue
            shutil.copyfile(src_lbl, dest_lbl)

# %% [markdown]
# ## Run through all src files

# %%
# Cycle through all source folders
for plant in all_plants:
    process_image_data(plant,log_level=1)
    print('====='*10)
# Out:
# Processing Canada Buffaloberry files in ./All_Plant_Data/Canada Buffaloberry/
# Last train file: CanadianBuffaloBerry_64699456 | Samples:83
# First test file: CanadianBuffaloBerry_186101743 | Last test file: CanadianBuffaloBerry_64125049 | Samples:16
# First valid file: CanadianBuffaloBerry_35767192 | Samples:12
#
# Completed processing Canada Buffaloberry files.
# ==================================================
# Processing Labrador Tea files in ./All_Plant_Data/Labrador Tea/
# Last train file: Labroder_tea_087 | Samples:75
# First test file: Labroder_tea_056 | Last test file: Labroder_tea_084 | Samples:15
# First valid file: Labroder_tea_009 (2) | Samples:11
#
# Completed processing Labrador Tea files.
# ==================================================
# Processing Prickly Rose files in ./All_Plant_Data/Prickly Rose/
# Last train file: Prickly-rose082 | Samples:75
# First test file: Prickly-Rose026 | Last test file: Prickly-Rose045 | Samples:15
# First valid file: Prickly-rose092 | Samples:10
#
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose091.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose100.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose087.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose076.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose050.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose053.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose023.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose036.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose073.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose028.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose048.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose041.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose094.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose095.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose069.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose031.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose057.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose013.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose054.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose019.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose056.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose009.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose004.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose085.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose088.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose055.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose089.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose096.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose024.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose084.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose062.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose071.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose068.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose043.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose008.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose099.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose010.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose046.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose079.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose083.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose077.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose040.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose006.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose093.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose033.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose061.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose018.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose074.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose014.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/prickly-rose063.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose058.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose049.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose052.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose011.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose012.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose007.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose075.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose022.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose065.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose034.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose032.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose070.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose044.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose039.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose098.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose025.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose080.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose066.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose086.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose015.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose090.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose051.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose017.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-Rose005.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/Prickly-rose082.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose026.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose021.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose035.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose001.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose047.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-rose059.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-rose097.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose029.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose037.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose042.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-rose072.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose003.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose016.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-rose078.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/Prickly-Rose045.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-rose092.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-Rose027.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-Rose030.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-rose067.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-rose064.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-rose081.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-rose060.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-Rose020.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-Rose038.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/Prickly-Rose002.txt
# Completed processing Prickly Rose files.
# ==================================================
# Processing Red-osier Dogwood files in ./All_Plant_Data/Red-osier Dogwood/
# Last train file: images (34) | Samples:104
# First test file: images (51) | Last test file: images (94) | Samples:21
# First valid file: images (75) | Samples:14
#
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (63).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (7).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (6) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (45).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (42).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134224.773.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (46).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (15).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (60).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (92).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (24).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (17).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134125.240.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (3) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/download (2).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (55).txt
# Label or Image file not found for imgres., skipping item...
# label: ./All_Plant_Data/Red-osier Dogwood/imgres..txt | img: ./All_Plant_Data/Red-osier Dogwood/imgres..jpg
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (98).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (77).txt
# Label or Image file not found for abcd., skipping item...
# label: ./All_Plant_Data/Red-osier Dogwood/abcd..txt | img: ./All_Plant_Data/Red-osier Dogwood/abcd..jpg
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (29).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134218.397.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (33).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (8) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (76).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (5).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (49).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134244.170.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (81).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (14).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (13).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (84).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (30).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (22).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (39).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (67).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (56).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134209.905.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (28).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (1).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (97).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134141.337.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (3).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (36).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (4) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (89).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (2) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (19).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (4).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (27).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (59).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (61).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (72).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (47).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (52).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (10).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (65).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134119.853.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134249.903.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (64).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/image.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/4-8-13-red-osier-dogwood-img_8874.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (48).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (6).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (96).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (54).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (44).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134149.592.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (8).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134204.298.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (73).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (88).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (35).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134153.919.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (74).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (95).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (70).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (71).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (80).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/download (1).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (93).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (2).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (62).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (99).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (79).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (16).txt
# ./All_Plant_Data/Red-osier Dogwood/RedOsierComposite.txt does not contain any data!
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/download (3).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (38).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (58).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (37).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (87).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (23).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (20).txt
# Label or Image file not found for object_names, skipping item...
# label: ./All_Plant_Data/Red-osier Dogwood/object_names.txt | img: ./All_Plant_Data/Red-osier Dogwood/object_names.jpg
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (9).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (66).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images - 2024-02-14T134114.451.txt
# Label or Image file not found for red-osier-dogwood-cornus-sericea-early-fruit-detail-redosier-berries-58096215., skipping item...
# label: ./All_Plant_Data/Red-osier Dogwood/red-osier-dogwood-cornus-sericea-early-fruit-detail-redosier-berries-58096215..txt | img: ./All_Plant_Data/Red-osier Dogwood/red-osier-dogwood-cornus-sericea-early-fruit-detail-redosier-berries-58096215..jpg
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/download 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (86).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (82).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/train/images (34).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (51).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (40).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (78).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (85).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images - 2024-02-14T134130.567.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (1) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/download (4).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (91).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (41).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (43).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (69).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (83).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (100).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (7) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (68).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (18).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/download.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (12).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images - 2024-02-14T134253.607.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/test/images (94).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (75).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (21).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (11).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (90).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (26).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (53).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (50).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (57).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images - 2024-02-14T134158.544.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (25).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (32).txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (5) 2.txt
# Updating labels in dataset ./TrainModels/datasets/Plant_Dataset_Updated/labels/valid/images (31).txt
# Label or Image file not found for imgres (1)., skipping item...
# label: ./All_Plant_Data/Red-osier Dogwood/imgres (1)..txt | img: ./All_Plant_Data/Red-osier Dogwood/imgres (1)..jpg
# Completed processing Red-osier Dogwood files.
# ==================================================
# Processing Velvet Leaved Blueberry files in ./All_Plant_Data/Velvet Leaved Blueberry/
# Last train file: velvet_blueberry_17 | Samples:96
# First test file: velvet_blueberry_6 | Last test file: velvet_blueberry_40 | Samples:20
# First valid file: velvet_blueberry_72 | Samples:13
#
# Label or Image file not found for velvet_blueberry_4, skipping item...
# label: ./All_Plant_Data/Velvet Leaved Blueberry/velvet_blueberry_4.txt | img: ./All_Plant_Data/Velvet Leaved Blueberry/velvet_blueberry_4.jpg
# Completed processing Velvet Leaved Blueberry files.
# ==================================================
